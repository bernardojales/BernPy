# %% [markdown]
# <a href="https://colab.research.google.com/github/Bernarsh/BernPy/blob/Bern/BERNARDO_PROJETO_PLANETAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from google.colab import files
uploaded = files.upload()

import io

df1 = pd.read_csv(io.BytesIO(uploaded['dados_planetas.csv']))

from matplotlib.pyplot import figure

figure(figsize=(15, 6), dpi=80)

#x= df1['mass']
#y = df1['gravity']
#z = df1['distance_from_sun']
#k= df1['length_of_day']
l= df1['mean_temperature']
#q= df1['number_of_moons']
p= df1['planet']

plt.bar(p, l, color='red', lw= 15)

#dataframe
df1.sort_values(by='mass', ascending=True)
# Out:
#      <input type="file" id="files-54eb3a7a-3478-4e86-8177-3c8e7e050760" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54eb3a7a-3478-4e86-8177-3c8e7e050760">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_planetas.csv to dados_planetas.csv
#     planet       mass  ...  has_ring_system  has_global_magnetic_field
# 8    Pluto     0.0146  ...               No                    Unknown
# 0  Mercury     0.3300  ...               No                        Yes
# 3     Mars     0.6420  ...               No                         No
# 1    Venus     4.8700  ...               No                         No
# 2    Earth     5.9700  ...               No                        Yes
# 6   Uranus    86.8000  ...              Yes                        Yes
# ...
