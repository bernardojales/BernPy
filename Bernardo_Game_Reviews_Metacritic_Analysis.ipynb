# %% [markdown]
# <a href="https://colab.research.google.com/github/Bernarsh/BernPy/blob/Bern/Bernardo_Game_Reviews_Metacritic_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" Aluno: Bernardo Jales
Disciplina: Programação aplicada à ciência de dados
Professor: Thyago Maia
Descrição:
Utilizarei um dataset de um site de reviews de jogos de videogame, chamado 'Metacritic' <https://www.metacritic.com/>

Jogos que datam desde o ano 2000

O dataset foi obtido pelo Kaggle, link a seguir:


Analisarei as tendências, as médias de análise


"""
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from google.colab import files

import io
jogos = pd.read_csv(io.BytesIO(data_to_load['metacritic_18.07.2021_csv.csv']))

filtro = jogos['metascore'] > 80.0
bem_avaliados = jogos[filtro]
bem_avaliados[['titles', 'platforms']]

print ("media", bem_avaliados.mean())

x = jogos['genre']
y = jogos['metascore']

plt.plot (x, y)
# Out:
# media metascore    85.111781
# dtype: float64
